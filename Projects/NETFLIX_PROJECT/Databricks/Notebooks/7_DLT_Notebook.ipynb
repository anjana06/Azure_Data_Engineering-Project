# %% [markdown]
# # **DLT NOTEBOOK - GOLD _LAYER_**

# %%
import dlt

# %%
looktables = {
    "rule1":"show_id is NOT null"
}

# %%
@dlt.table(
    name="gold_netflixdirectors"
)
@dlt.expect_all_or_drop(looktables)
def myfun():
    df = spark.readStream.format("delta").load("abfss://sliver@netflixprojectdlanju.dfs.core.windows.net/netflix_directors")
    return df

# %%
@dlt.table(
    name="gold_netflixcast"
)
@dlt.expect_all_or_drop(looktables)

def myfun():
    df = spark.readStream.format("delta").load("abfss://sliver@netflixprojectdlanju.dfs.core.windows.net/netflix_cast")
    return df

# %%
@dlt.table(
    name="gold_netflixcountries"
)
@dlt.expect_all_or_drop(looktables)

def myfun():
    df = spark.readStream.format("delta").load("abfss://sliver@netflixprojectdlanju.dfs.core.windows.net/netflix_countries")
    return df

# %%
@dlt.table(
    name="gold_netflixcategory"
)
@dlt.expect_or_drop("rule1","show_id is NOT null")

def myfun():
    df = spark.readStream.format("delta").load("abfss://sliver@netflixprojectdlanju.dfs.core.windows.net/netflix_category")
    return df

# %%
@dlt.table

def gold_stg_netflixtitles():
    df = spark.readStream.format("delta").load("abfss://sliver@netflixprojectdlanju.dfs.core.windows.net/netflix_titles")
    return df

# %%
from pyspark.sql.functions import *

# %%
@dlt.view

def gold_tran_netflixtitles():
    df = spark.readStream.table("LIVE.gold_stg_netflixtitles")
    df = df.withColumn("newflag",lit(1))
    return df

# %%
masterdata_rules = {
    "rule1":"newflag is NOT NULL",
    "rule2":"show_id is NOT NULL"
}

# %%
@dlt.table
@dlt.expect_all_or_drop(masterdata_rules)
def gold_netflixtitles():
    df = spark.readStream.table("LIVE.gold_tran_netflixtitles")
    return df
